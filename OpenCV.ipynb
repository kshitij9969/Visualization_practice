# %% [markdown]
# <a href="https://colab.research.google.com/github/kshitij9969/Visualization_practice/blob/main/OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt

# %%
image = Image.open("/content/test.jpg")

# %%
print(image.format, image.size, image.mode)
# Out:
# JPEG (1280, 720) RGB

# %%
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x7F74E0A932D0>

# %%
x = 575
y = 484
width = 235
height = 222
resolution_x = image.size[0]
resolution_y = image.size[1]
# box = (x, resolution_y - y, x + width, resolution_y - y + height)
box = (x, y, x + width, y + height)
draw = ImageDraw.Draw(image)
draw.rectangle([575, 484,575 + 235, 484 + 222], outline ="red", width=3)

# %%
cropped_region = image.crop(box)

# %%
display(cropped_region)
# Out:
# <PIL.Image.Image image mode=RGB size=235x222 at 0x7F74E013A2D0>
